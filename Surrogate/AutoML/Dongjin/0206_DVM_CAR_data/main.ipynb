# %%
from evaluate import evaluate_autoML, evaluate_auto_scikit, evaluate_tpot
import pandas as pd
import os
import sys

def rename_index_if_exists(df, index):
    if not index in df.index:
        return index

    num = 0
    while (num < 1000):
        new_index = f'{index}_{num}'
        if not new_index in df.index:
            break
        num += 1
    return new_index


def load_data(drop_categorical, target):
    # drop_categorical = True
    # target = 'Annual_revenue'
    
    data_dir_path = "data"
    train = pd.read_csv(data_dir_path + '/train.csv')
    test = pd.read_csv(data_dir_path + '/test.csv')
    n_train = len(train)
    combined = pd.concat([train, test], axis=0)

    if drop_categorical:
        string_cols = combined.select_dtypes(include=['object']).columns
        combined = combined.drop(columns=string_cols)
    else:
        combined = pd.get_dummies(combined)

    train = combined.iloc[:n_train, :]
    test = combined.iloc[n_train:, :]

    X_train = train.drop(columns=[target])
    y_train = train[target]
    X_test = test.drop(columns=[target])
    y_test = test[target]

    return X_train, y_train, X_test, y_test

# %%
mode = 'autoML'
        
rel_data_dir_path = 'data'
rel_save_path = 'result/DVM-CAR.csv'

py_dir_path = ""
data_dir_path = os.path.join(py_dir_path, rel_data_dir_path)
save_path = os.path.join(py_dir_path, rel_save_path)

drop_categorical = False
target = 'Annual_revenue'
X_train, y_train, X_test, y_test = load_data(drop_categorical, target)


func_dicts = {'autoML': {'func': evaluate_autoML, 'args': {'n_generation': 6}},
            'auto-scikitlearn': {'func': evaluate_auto_scikit, 'args': {'target_time': 80}},
            'tpot': {'func': evaluate_tpot, 'args': {'generations': 3}}}

func = func_dicts[mode]['func']
args = func_dicts[mode]['args']
result = func(X_train, y_train, X_test, y_test, **args)
result['args'] = args
result['drop_categorical'] = drop_categorical
result['target'] = target

if os.path.exists(save_path):
    df = pd.read_csv(save_path, index_col='func')
else:
    df = pd.DataFrame(columns=result.keys())
    df.index.name = 'func'

index = rename_index_if_exists(df, mode)
df.loc[index] = result

os.makedirs(os.path.dirname(save_path), exist_ok=True)
df.to_csv(save_path)
# Out:
# [2025-02-07 05:34:06] AutoML.__init__() - n_population: 30, n_generation: 6, n_parent: 5, prob_mutations: [0.2, 0.5], use_joblib: True, n_jobs: -1
# [2025-02-07 05:34:06] AutoML.fit() - use_kfold: True, kfold: 5, valid_size: 0.2000, seed: 42, max_n_try: 1000, timeout: 30
# Structure-3 - valid r2: 0.5471±0.1100
# Structure-6 - valid r2: -0.0389±0.2309
# Structure-2 - valid r2: 0.5748±0.0682
# Structure-5 - valid r2: 0.8090±0.1178
# Structure-0 - valid r2: 0.5333±0.0995
# Structure-10 - valid r2: 0.4788±0.0959
# Structure-9 - valid r2: 0.7659±0.0571
# Structure-13 - valid r2: 0.8290±0.0227
# Structure-8 - valid r2: 0.7768±0.0467
# Structure-15 - valid r2: 0.5480±0.1134
# Structure-11 - valid r2: 0.7783±0.0496
# Structure-17 - valid r2: 0.4571±0.0871
# Structure-16 - valid r2: 0.8303±0.0482
# Structure-4 - valid r2: 0.8742±0.0082
# Structure-1 - valid r2: 0.8830±0.0179
# Structure-20 - valid r2: 0.8358±0.0486
# Structure-19 - valid r2: 0.7733±0.0404
# Structure-23 - valid r2: 0.8087±0.0449
# Structure-24 - valid r2: 0.5334±0.0994
# Structure-22 - valid r2: 0.7768±0.0470
# Structure-25 - valid r2: 0.8177±0.0517
# Structure-27 - valid r2: 0.0346±0.1821
# Structure-21 - valid r2: 0.8801±0.0168
# Structure-29 - valid r2: 0.8237±0.1047
# Structure-7 - valid r2: 0.1015±0.1907
# Structure-12 - valid r2: -1.0821±1.2532
# Timeout: pipeline.fit did not complete in given time.
# Structure-14 - valid r2: -100.0000±-100.0000
# Timeout: pipeline.fit did not complete in given time.
# Structure-18 - valid r2: -100.0000±-100.0000
# Timeout: pipeline.fit did not complete in given time.
# Structure-26 - valid r2: -100.0000±-100.0000
# Timeout: pipeline.fit did not complete in given time.
# Structure-28 - valid r2: -100.0000±-100.0000
# [2025-02-07 05:34:58] 1 - best R2: 0.883
# [2025-02-07 05:34:58]
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 100) - 0.8830±0.0179
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 100) - 0.8801±0.0168
# (StandardScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 100) - 0.8742±0.0082
# (RobustScaler) - (VarianceThreshold) - (DecisionTreeRegressor) - 0.8358±0.0486
# (RobustScaler) - (VarianceThreshold) - (DecisionTreeRegressor) - 0.8303±0.0482
# (StandardScaler) - (passthrough) - (DecisionTreeRegressor) - 0.8290±0.0227
# (RobustScaler) - (VarianceThreshold) - (XGBRegressor: n_estimators: 100, learning_rate: 0.1000, max_depth: 6) - 0.8237±0.1047
# (passthrough) - (VarianceThreshold) - (DecisionTreeRegressor) - 0.8177±0.0517
# (StandardScaler) - (SelectPercentile) - (XGBRegressor: n_estimators: 100, learning_rate: 0.1000, max_depth: 6) - 0.8090±0.1178
# (RobustScaler) - (VarianceThreshold) - (DecisionTreeRegressor) - 0.8087±0.0449
# (StandardScaler) - (VarianceThreshold) - (GradientBoostingRegressor: n_estimators: 100, learning_rate: 0.1000) - 0.7783±0.0496
# (passthrough) - (VarianceThreshold) - (GradientBoostingRegressor: n_estimators: 100, learning_rate: 0.1000) - 0.7768±0.0467
# (passthrough) - (passthrough) - (GradientBoostingRegressor: n_estimators: 100, learning_rate: 0.1000) - 0.7768±0.0470
# (RobustScaler) - (VarianceThreshold) - (GradientBoostingRegressor: n_estimators: 100, learning_rate: 0.1000) - 0.7733±0.0404
# (RobustScaler) - (SelectPercentile) - (GradientBoostingRegressor: n_estimators: 100, learning_rate: 0.1000) - 0.7659±0.0571
# (StandardScaler) - (SelectKBest) - (XGBRegressor: n_estimators: 100, learning_rate: 0.1000, max_depth: 6) - 0.5748±0.0682
# (RobustScaler) - (SelectKBest) - (DecisionTreeRegressor) - 0.5480±0.1134
# (passthrough) - (SelectKBest) - (DecisionTreeRegressor) - 0.5471±0.1100
# (RobustScaler) - (SelectKBest) - (GradientBoostingRegressor: n_estimators: 100, learning_rate: 0.1000) - 0.5334±0.0994
# (StandardScaler) - (SelectKBest) - (GradientBoostingRegressor: n_estimators: 100, learning_rate: 0.1000) - 0.5333±0.0995
# (StandardScaler) - (SelectKBest) - (KNeighborsRegressor: n_neighbors: 5) - 0.4788±0.0959
# (RobustScaler) - (SelectKBest) - (KNeighborsRegressor: n_neighbors: 5) - 0.4571±0.0871
# (PolynomialFeatures) - (SelectKBest) - (RandomForestRegressor: n_estimators: 100) - 0.1015±0.1907
# (passthrough) - (passthrough) - (KNeighborsRegressor: n_neighbors: 5) - 0.0346±0.1821
# (passthrough) - (SelectPercentile) - (KNeighborsRegressor: n_neighbors: 5) - -0.0389±0.2309
# (PolynomialFeatures) - (SelectKBest) - (KNeighborsRegressor: n_neighbors: 5) - -1.0821±1.2532
# (PolynomialFeatures) - (VarianceThreshold) - (XGBRegressor: n_estimators: 100, learning_rate: 0.1000, max_depth: 6) - -100.0000±-100.0000
# (PolynomialFeatures) - (passthrough) - (GradientBoostingRegressor: n_estimators: 100, learning_rate: 0.1000) - -100.0000±-100.0000
# (RobustScaler) - (VarianceThreshold) - (RandomForestRegressor: n_estimators: 100) - -100.0000±-100.0000
# (RobustScaler) - (VarianceThreshold) - (RandomForestRegressor: n_estimators: 100) - -100.0000±-100.0000
# Structure-8 - valid r2: 0.8093±0.0157
# Structure-5 - valid r2: 0.8277±0.0377
# Structure-10 - valid r2: 0.8279±0.0284
# Structure-12 - valid r2: 0.8207±0.0309
# Structure-13 - valid r2: 0.5480±0.1134
# Structure-14 - valid r2: 0.8212±0.0062
# Structure-15 - valid r2: 0.8207±0.0260
# Structure-17 - valid r2: 0.5480±0.1134
# Structure-9 - valid r2: 0.8087±0.0276
# Structure-19 - valid r2: 0.8367±0.0440
# Structure-20 - valid r2: 0.5480±0.1134
# Structure-21 - valid r2: 0.5484±0.1125
# Structure-23 - valid r2: 0.8352±0.0452
# Structure-22 - valid r2: 0.5956±0.0648
# Structure-7 - valid r2: 0.8794±0.0151
# Structure-26 - valid r2: 0.5484±0.1126
# Structure-27 - valid r2: 0.8281±0.0491
# Structure-24 - valid r2: 0.8448±0.0280
# Structure-6 - valid r2: 0.8782±0.0121
# Structure-29 - valid r2: 0.8342±0.0215
# Structure-28 - valid r2: 0.7663±0.0518
# Structure-18 - valid r2: 0.8794±0.0110
# Structure-11 - valid r2: 0.8743±0.0142
# Structure-25 - valid r2: 0.8779±0.0141
# Timeout: pipeline.fit did not complete in given time.
# Structure-16 - valid r2: -100.0000±-100.0000
# [2025-02-07 05:35:32] 2 - best R2: 0.883
# [2025-02-07 05:35:32]
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 100) - 0.8830±0.0179
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 100) - 0.8801±0.0168
# (passthrough) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 100) - 0.8794±0.0110
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 73) - 0.8794±0.0151
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 100) - 0.8782±0.0121
# (StandardScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 73) - 0.8779±0.0141
# (StandardScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 130) - 0.8743±0.0142
# (StandardScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 100) - 0.8742±0.0082
# (StandardScaler) - (passthrough) - (GradientBoostingRegressor: n_estimators: 54, learning_rate: 0.3758) - 0.8448±0.0280
# (RobustScaler) - (VarianceThreshold) - (DecisionTreeRegressor) - 0.8367±0.0440
# (RobustScaler) - (VarianceThreshold) - (DecisionTreeRegressor) - 0.8358±0.0486
# (passthrough) - (VarianceThreshold) - (DecisionTreeRegressor) - 0.8352±0.0452
# (StandardScaler) - (VarianceThreshold) - (DecisionTreeRegressor) - 0.8342±0.0215
# (RobustScaler) - (VarianceThreshold) - (DecisionTreeRegressor) - 0.8303±0.0482
# (passthrough) - (VarianceThreshold) - (DecisionTreeRegressor) - 0.8281±0.0491
# (passthrough) - (VarianceThreshold) - (DecisionTreeRegressor) - 0.8279±0.0284
# (RobustScaler) - (VarianceThreshold) - (DecisionTreeRegressor) - 0.8277±0.0377
# (RobustScaler) - (passthrough) - (DecisionTreeRegressor) - 0.8212±0.0062
# (RobustScaler) - (SelectPercentile) - (DecisionTreeRegressor) - 0.8207±0.0260
# (RobustScaler) - (SelectPercentile) - (DecisionTreeRegressor) - 0.8207±0.0309
# (StandardScaler) - (SelectPercentile) - (DecisionTreeRegressor) - 0.8093±0.0157
# (StandardScaler) - (VarianceThreshold) - (GradientBoostingRegressor: n_estimators: 66, learning_rate: 0.1978) - 0.8087±0.0276
# (passthrough) - (SelectPercentile) - (GradientBoostingRegressor: n_estimators: 100, learning_rate: 0.1000) - 0.7663±0.0518
# (StandardScaler) - (SelectKBest) - (RandomForestRegressor: n_estimators: 73) - 0.5956±0.0648
# (StandardScaler) - (SelectKBest) - (DecisionTreeRegressor) - 0.5484±0.1125
# (StandardScaler) - (SelectKBest) - (DecisionTreeRegressor) - 0.5484±0.1126
# (RobustScaler) - (SelectKBest) - (DecisionTreeRegressor) - 0.5480±0.1134
# (RobustScaler) - (SelectKBest) - (DecisionTreeRegressor) - 0.5480±0.1134
# (RobustScaler) - (SelectKBest) - (DecisionTreeRegressor) - 0.5480±0.1134
# (passthrough) - (VarianceThreshold) - (RandomForestRegressor: n_estimators: 117) - -100.0000±-100.0000
# Structure-8 - valid r2: 0.8759±0.0116
# Structure-9 - valid r2: 0.8774±0.0178
# Structure-6 - valid r2: 0.8801±0.0194
# Structure-10 - valid r2: 0.8734±0.0051
# Structure-15 - valid r2: 0.8826±0.0145
# Structure-11 - valid r2: 0.1009±0.1924
# Structure-14 - valid r2: 0.8787±0.0195
# Timeout: pipeline.fit did not complete in given time.
# Structure-5 - valid r2: -100.0000±-100.0000
# Timeout: pipeline.fit did not complete in given time.
# Structure-7 - valid r2: -100.0000±-100.0000
# Structure-16 - valid r2: 0.8811±0.0151
# Structure-13 - valid r2: 0.0993±0.1892
# Timeout: pipeline.fit did not complete in given time.
# Structure-12 - valid r2: -100.0000±-100.0000
# Structure-17 - valid r2: 0.8732±0.0064
# Structure-20 - valid r2: 0.8830±0.0121
# Structure-21 - valid r2: 0.8775±0.0112
# Structure-22 - valid r2: 0.8792±0.0136
# Structure-25 - valid r2: 0.8724±0.0096
# Structure-28 - valid r2: 0.7075±0.0724
# Structure-26 - valid r2: 0.8741±0.0089
# Structure-23 - valid r2: 0.8821±0.0171
# Timeout: pipeline.fit did not complete in given time.
# Structure-18 - valid r2: -100.0000±-100.0000
# Timeout: pipeline.fit did not complete in given time.
# Structure-19 - valid r2: -100.0000±-100.0000
# Structure-27 - valid r2: 0.8791±0.0123
# Timeout: pipeline.fit did not complete in given time.
# Structure-24 - valid r2: -100.0000±-100.0000
# Structure-29 - valid r2: 0.8867±0.0147
# [2025-02-07 05:36:52] 3 - best R2: 0.887
# [2025-02-07 05:36:52]
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 199) - 0.8867±0.0147
# (passthrough) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 100) - 0.8830±0.0121
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 100) - 0.8830±0.0179
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 96) - 0.8826±0.0145
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 174) - 0.8821±0.0171
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 79) - 0.8811±0.0151
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 100) - 0.8801±0.0194
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 100) - 0.8801±0.0168
# (passthrough) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 100) - 0.8794±0.0110
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 73) - 0.8794±0.0151
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 79) - 0.8792±0.0136
# (passthrough) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 181) - 0.8791±0.0123
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 161) - 0.8787±0.0195
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 100) - 0.8782±0.0121
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 100) - 0.8775±0.0112
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 73) - 0.8774±0.0178
# (passthrough) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 69) - 0.8759±0.0116
# (StandardScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 100) - 0.8741±0.0089
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 96) - 0.8734±0.0051
# (passthrough) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 100) - 0.8732±0.0064
# (passthrough) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 100) - 0.8724±0.0096
# (RobustScaler) - (SelectPercentile) - (GradientBoostingRegressor: n_estimators: 60, learning_rate: 0.1000) - 0.7075±0.0724
# (PolynomialFeatures) - (SelectKBest) - (RandomForestRegressor: n_estimators: 188) - 0.1009±0.1924
# (PolynomialFeatures) - (SelectKBest) - (RandomForestRegressor: n_estimators: 281) - 0.0993±0.1892
# (PolynomialFeatures) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 100) - -100.0000±-100.0000
# (RobustScaler) - (VarianceThreshold) - (RandomForestRegressor: n_estimators: 150) - -100.0000±-100.0000
# (RobustScaler) - (VarianceThreshold) - (RandomForestRegressor: n_estimators: 96) - -100.0000±-100.0000
# (RobustScaler) - (VarianceThreshold) - (RandomForestRegressor: n_estimators: 96) - -100.0000±-100.0000
# (PolynomialFeatures) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 150) - -100.0000±-100.0000
# (RobustScaler) - (VarianceThreshold) - (RandomForestRegressor: n_estimators: 104) - -100.0000±-100.0000
# Structure-6 - valid r2: 0.7655±0.0550
# Structure-5 - valid r2: 0.8766±0.0186
# Structure-13 - valid r2: 0.8806±0.0205
# Structure-11 - valid r2: 0.8815±0.0123
# Structure-7 - valid r2: 0.8790±0.0161
# Structure-8 - valid r2: 0.8792±0.0175
# Structure-14 - valid r2: 0.8777±0.0068
# Structure-17 - valid r2: 0.5736±0.0717
# Structure-16 - valid r2: 0.5886±0.0559
# Structure-9 - valid r2: 0.8820±0.0160
# Timeout: pipeline.fit did not complete in given time.
# Structure-10 - valid r2: -100.0000±-100.0000
# Timeout: pipeline.fit did not complete in given time.
# Structure-12 - valid r2: -100.0000±-100.0000
# Structure-22 - valid r2: 0.7711±0.0585
# Structure-19 - valid r2: 0.8823±0.0171
# Structure-15 - valid r2: 0.8846±0.0186
# Structure-23 - valid r2: 0.5898±0.0628
# Structure-26 - valid r2: 0.5976±0.0748
# Structure-28 - valid r2: 0.7316±0.1262
# Structure-20 - valid r2: 0.8813±0.0197
# Structure-21 - valid r2: 0.8785±0.0132
# Structure-29 - valid r2: 0.8160±0.0416
# Structure-18 - valid r2: 0.8741±0.0050
# Structure-25 - valid r2: 0.8818±0.0192
# Structure-24 - valid r2: 0.8802±0.0183
# Timeout: pipeline.fit did not complete in given time.
# Structure-27 - valid r2: -100.0000±-100.0000
# [2025-02-07 05:38:06] 4 - best R2: 0.887
# [2025-02-07 05:38:06]
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 199) - 0.8867±0.0147
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 132) - 0.8846±0.0186
# (passthrough) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 100) - 0.8830±0.0121
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 100) - 0.8830±0.0179
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 96) - 0.8826±0.0145
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 111) - 0.8823±0.0171
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 174) - 0.8821±0.0171
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 234) - 0.8820±0.0160
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 147) - 0.8818±0.0192
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 174) - 0.8815±0.0123
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 132) - 0.8813±0.0197
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 53) - 0.8806±0.0205
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 199) - 0.8802±0.0183
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 199) - 0.8792±0.0175
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 199) - 0.8790±0.0161
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 132) - 0.8785±0.0132
# (passthrough) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 100) - 0.8777±0.0068
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 53) - 0.8766±0.0186
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 199) - 0.8741±0.0050
# (RobustScaler) - (SelectPercentile) - (GradientBoostingRegressor: n_estimators: 100, learning_rate: 0.1752) - 0.8160±0.0416
# (RobustScaler) - (SelectPercentile) - (GradientBoostingRegressor: n_estimators: 100, learning_rate: 0.1000) - 0.7711±0.0585
# (RobustScaler) - (SelectPercentile) - (GradientBoostingRegressor: n_estimators: 100, learning_rate: 0.1000) - 0.7655±0.0550
# (passthrough) - (SelectPercentile) - (XGBRegressor: n_estimators: 100, learning_rate: 0.1000, max_depth: 3) - 0.7316±0.1262
# (RobustScaler) - (SelectKBest) - (RandomForestRegressor: n_estimators: 103) - 0.5976±0.0748
# (passthrough) - (SelectKBest) - (RandomForestRegressor: n_estimators: 446) - 0.5898±0.0628
# (passthrough) - (SelectKBest) - (RandomForestRegressor: n_estimators: 230) - 0.5886±0.0559
# (passthrough) - (SelectKBest) - (XGBRegressor: n_estimators: 100, learning_rate: 0.0872, max_depth: 6) - 0.5736±0.0717
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 277) - -100.0000±-100.0000
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 368) - -100.0000±-100.0000
# (passthrough) - (VarianceThreshold) - (RandomForestRegressor: n_estimators: 267) - -100.0000±-100.0000
# Structure-5 - valid r2: 0.7943±0.0267
# Structure-10 - valid r2: 0.8696±0.0074
# Structure-12 - valid r2: 0.8823±0.0175
# Structure-8 - valid r2: 0.8801±0.0183
# Structure-15 - valid r2: 0.8205±0.0392
# Structure-14 - valid r2: 0.8826±0.0185
# Timeout: pipeline.fit did not complete in given time.
# Structure-6 - valid r2: -100.0000±-100.0000
# Timeout: pipeline.fit did not complete in given time.
# Structure-7 - valid r2: -100.0000±-100.0000
# Structure-17 - valid r2: 0.7412±0.0693
# Structure-20 - valid r2: 0.8202±0.0418
# Timeout: pipeline.fit did not complete in given time.
# Structure-11 - valid r2: -100.0000±-100.0000
# Timeout: pipeline.fit did not complete in given time.
# Structure-9 - valid r2: -100.0000±-100.0000
# Structure-13 - valid r2: 0.8765±0.0097
# Structure-24 - valid r2: -0.0823±0.1937
# Structure-19 - valid r2: 0.8734±0.0069
# Structure-21 - valid r2: 0.8790±0.0140
# Structure-22 - valid r2: 0.8822±0.0201
# Timeout: pipeline.fit did not complete in given time.
# Structure-16 - valid r2: -100.0000±-100.0000
# Timeout: pipeline.fit did not complete in given time.
# Structure-18 - valid r2: -100.0000±-100.0000
# Timeout: pipeline.fit did not complete in given time.
# Structure-23 - valid r2: -100.0000±-100.0000
# Timeout: pipeline.fit did not complete in given time.
# Structure-25 - valid r2: -100.0000±-100.0000
# Structure-28 - valid r2: 0.8787±0.0111
# Timeout: pipeline.fit did not complete in given time.
# Structure-26 - valid r2: -100.0000±-100.0000
# Timeout: pipeline.fit did not complete in given time.
# Structure-27 - valid r2: -100.0000±-100.0000
# Structure-29 - valid r2: 0.8815±0.0178
# [2025-02-07 05:39:29] 5 - best R2: 0.887
# [2025-02-07 05:39:29]
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 199) - 0.8867±0.0147
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 132) - 0.8846±0.0186
# (passthrough) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 100) - 0.8830±0.0121
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 100) - 0.8830±0.0179
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 96) - 0.8826±0.0145
# (passthrough) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 145) - 0.8826±0.0185
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 96) - 0.8823±0.0175
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 157) - 0.8822±0.0201
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 199) - 0.8815±0.0178
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 198) - 0.8801±0.0183
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 121) - 0.8790±0.0140
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 152) - 0.8787±0.0111
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 199) - 0.8765±0.0097
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 90) - 0.8734±0.0069
# (passthrough) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 100) - 0.8696±0.0074
# (RobustScaler) - (SelectPercentile) - (GradientBoostingRegressor: n_estimators: 100, learning_rate: 0.1943) - 0.8205±0.0392
# (RobustScaler) - (SelectPercentile) - (DecisionTreeRegressor) - 0.8202±0.0418
# (RobustScaler) - (SelectPercentile) - (DecisionTreeRegressor) - 0.7943±0.0267
# (RobustScaler) - (SelectPercentile) - (KNeighborsRegressor: n_neighbors: 4) - 0.7412±0.0693
# (passthrough) - (SelectPercentile) - (KNeighborsRegressor: n_neighbors: 2) - -0.0823±0.1937
# (PolynomialFeatures) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 100) - -100.0000±-100.0000
# (PolynomialFeatures) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 100) - -100.0000±-100.0000
# (PolynomialFeatures) - (passthrough) - (KNeighborsRegressor: n_neighbors: 3) - -100.0000±-100.0000
# (PolynomialFeatures) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 152) - -100.0000±-100.0000
# (PolynomialFeatures) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 198) - -100.0000±-100.0000
# (PolynomialFeatures) - (VarianceThreshold) - (KNeighborsRegressor: n_neighbors: 3) - -100.0000±-100.0000
# (PolynomialFeatures) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 217) - -100.0000±-100.0000
# (PolynomialFeatures) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 132) - -100.0000±-100.0000
# (RobustScaler) - (passthrough) - (RandomForestRegressor: n_estimators: 157) - -100.0000±-100.0000
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 366) - -100.0000±-100.0000
# Structure-6 - valid r2: 0.8786±0.0093
# Structure-10 - valid r2: 0.8799±0.0250
# Structure-5 - valid r2: 0.8763±0.0058
# Structure-9 - valid r2: 0.8779±0.0157
# Structure-15 - valid r2: 0.8367±0.1042
# Structure-7 - valid r2: 0.8782±0.0104
# Structure-12 - valid r2: 0.8825±0.0212
# Structure-11 - valid r2: 0.8774±0.0049
# Structure-8 - valid r2: 0.8828±0.0161
# Structure-20 - valid r2: 0.7416±0.0655
# Structure-17 - valid r2: 0.8848±0.0176
# Structure-18 - valid r2: 0.8769±0.0126
# Timeout: pipeline.fit did not complete in given time.
# Structure-13 - valid r2: -100.0000±-100.0000
# Structure-23 - valid r2: 0.6004±0.0699
# Structure-14 - valid r2: 0.8816±0.0154
# Structure-21 - valid r2: 0.8822±0.0224
# Timeout: pipeline.fit did not complete in given time.
# Structure-16 - valid r2: -100.0000±-100.0000
# Structure-19 - valid r2: 0.8764±0.0127
# Structure-29 - valid r2: 0.7496±0.1212
# Timeout: pipeline.fit did not complete in given time.
# Structure-22 - valid r2: -100.0000±-100.0000
# Structure-24 - valid r2: 0.0993±0.1875
# Timeout: pipeline.fit did not complete in given time.
# Structure-26 - valid r2: -100.0000±-100.0000
# Timeout: pipeline.fit did not complete in given time.
# Structure-25 - valid r2: -100.0000±-100.0000
# Structure-27 - valid r2: 0.8776±0.0044
# Structure-28 - valid r2: 0.8804±0.0173
# [2025-02-07 05:40:47] 6 - best R2: 0.887
# [2025-02-07 05:40:47]
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 199) - 0.8867±0.0147
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 139) - 0.8848±0.0176
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 132) - 0.8846±0.0186
# (passthrough) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 100) - 0.8830±0.0121
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 100) - 0.8830±0.0179
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 256) - 0.8828±0.0161
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 96) - 0.8826±0.0145
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 132) - 0.8825±0.0212
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 132) - 0.8822±0.0224
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 256) - 0.8816±0.0154
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 241) - 0.8804±0.0173
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 96) - 0.8799±0.0250
# (StandardScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 96) - 0.8786±0.0093
# (StandardScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 199) - 0.8782±0.0104
# (StandardScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 143) - 0.8779±0.0157
# (passthrough) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 256) - 0.8776±0.0044
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 241) - 0.8774±0.0049
# (StandardScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 116) - 0.8769±0.0126
# (StandardScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 256) - 0.8764±0.0127
# (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 132) - 0.8763±0.0058
# (passthrough) - (SelectPercentile) - (XGBRegressor: n_estimators: 164, learning_rate: 0.1000, max_depth: 6) - 0.8367±0.1042
# (StandardScaler) - (SelectPercentile) - (XGBRegressor: n_estimators: 100, learning_rate: 0.1213, max_depth: 3) - 0.7496±0.1212
# (RobustScaler) - (SelectPercentile) - (GradientBoostingRegressor: n_estimators: 67, learning_rate: 0.1146) - 0.7416±0.0655
# (RobustScaler) - (SelectKBest) - (RandomForestRegressor: n_estimators: 132) - 0.6004±0.0699
# (PolynomialFeatures) - (SelectKBest) - (RandomForestRegressor: n_estimators: 236) - 0.0993±0.1875
# (PolynomialFeatures) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 96) - -100.0000±-100.0000
# (PolynomialFeatures) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 142) - -100.0000±-100.0000
# (PolynomialFeatures) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 106) - -100.0000±-100.0000
# (PolynomialFeatures) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 241) - -100.0000±-100.0000
# (PolynomialFeatures) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 236) - -100.0000±-100.0000
# [2025-02-07 05:40:47] Best structure
# [2025-02-07 05:40:47] (RobustScaler) - (SelectPercentile) - (RandomForestRegressor: n_estimators: 199) - 0.8867±0.0147
#
# Evaluation for train:
# R2 Score: 0.9613
# Mean Absolute Error (MAE): 18412058.4844
# Root Mean Squared Error (RMSE): 40606749.7983
#
# Evaluation for test:
# R2 Score: 0.8237
# Mean Absolute Error (MAE): 43026891.3842
# Root Mean Squared Error (RMSE): 92602007.5189
# [2025-02-07 05:40:47] AutoML init to training finished in: 401.3 s
# [2025-02-07 05:40:47] Evaluation - Train - R2: 0.9613, MAE: 18412058.4844, RMSE: 40606749.7983
# [2025-02-07 05:40:47] Evaluation - Test - R2: 0.8237, MAE: 43026891.3842, RMSE: 92602007.5189
