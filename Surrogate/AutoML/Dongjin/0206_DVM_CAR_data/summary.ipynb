# %%
import pandas as pd

# %%
result_path = 'result/DVM-CAR.csv'
df = pd.read_csv(result_path, index_col='func')

# %%
df[['test_R2', 'test_MAE', 'test_RMSE',	'elapsed_time']]
# Out:
#                    test_R2      test_MAE     test_RMSE  elapsed_time
# func
# autoML            0.820132  4.328675e+07  9.354727e+07    407.147372
# tpot              0.609034  6.365961e+07  1.379190e+08    996.192049
# auto-scikitlearn  0.881216  3.519758e+07  7.602109e+07    402.578601

# %%
df
# Out:
#                   train_R2  train_adjusted_R2     train_MAE    train_RMSE  \
# func
# autoML            0.956537           0.939182  1.887023e+07  4.302168e+07
# tpot              0.892355           0.849374  4.436490e+07  6.770510e+07
# auto-scikitlearn  0.962973           0.948189  2.234601e+07  3.970844e+07
#
#                    test_R2  test_adjusted_R2      test_MAE     test_RMSE  \
# func
# autoML            0.820132              -100  4.328675e+07  9.354727e+07
# tpot              0.609034              -100  6.365961e+07  1.379190e+08
# auto-scikitlearn  0.881216              -100  3.519758e+07  7.602109e+07
#
#                   elapsed_time                  args  drop_categorical  \
# func
# autoML              407.147372   {'n_generation': 6}             False
# tpot                996.192049    {'generations': 1}             False
# auto-scikitlearn    402.578601  {'target_time': 400}             False
#
#                           target
# func
# ...
