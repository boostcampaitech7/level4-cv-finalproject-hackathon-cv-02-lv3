# %%
import pandas as pd

# %%
result_path = 'result/DVM-CAR_stylish_test.csv'
df = pd.read_csv(result_path)
df[['mode', 'drop_categorical', 'drop_stylish', 'target', 'test_R2', 'test_MAE', 'test_RMSE',	'elapsed_time']]
# Out:
#                mode  drop_categorical  drop_stylish          target   test_R2  \
# 0            autoML             False          True  Annual_revenue  0.850504
# 1            autoML             False         False  Annual_revenue  0.826756
# 2  auto-scikitlearn             False          True  Annual_revenue  0.854830
# 3  auto-scikitlearn             False         False  Annual_revenue  0.834392
# 4            autoML              True          True  Annual_revenue  0.901439
# 5            autoML              True         False  Annual_revenue  0.875617
# 6  auto-scikitlearn              True          True  Annual_revenue  0.909299
# 7  auto-scikitlearn              True         False  Annual_revenue  0.905451
# 8            autoML              True          True     Entry_price  0.990193
# 9            autoML              True         False     Entry_price  0.988809
#
#        test_MAE     test_RMSE  elapsed_time
# 0  3.514065e+07  8.528437e+07    465.636141
# ...

# %%
result_path = 'result/DVM-CAR_stylish_test.csv'
df = pd.read_csv(result_path)
df[['mode', 'drop_categorical', 'drop_stylish', 'target', 'test_R2', 'test_MAE', 'test_RMSE',	'elapsed_time']]
