# %%
import matplotlib
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D

# %%
# CSV 파일 로드
df_original = pd.read_csv("melb_split.csv")
#df_all = pd.read_csv("optimized_all.csv")  # 전체 최적화 결과
#df_row_iter_10 = pd.read_csv("optimized_solutions.csv")  # 행별 최적화 결과
#df_row_add_building_area = pd.read_csv("optimized_solutions_add_BuildingArea.csv")  # 행별 최적화 결과
df_row_add_building_area_2 = pd.read_csv("optimized_solutions_add_BuildingArea_2.csv")  # 행별 최적화 결과
#df_row_iter_20 = pd.read_csv("optimized_solutions_2.csv")

# %% [markdown]
# ## 기존 CSV

# %%
# 📌 1️⃣ 최적화된 위치 시각화 (위도-경도 산점도)
plt.figure(figsize=(10, 6))
scatter = plt.scatter(df_original["Longtitude"], df_original["Lattitude"], c=df_original["Price"], cmap='viridis', alpha=0.8)
plt.colorbar(scatter, label="Price")
plt.xlabel("Longtitude (경도)")
plt.ylabel("Lattitude (위도)")
plt.title("📍 최적화된 위치와 예측 가격 (Scatter Plot)")
plt.show()
# Out:
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 128205 (\N{ROUND PUSHPIN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 52572 (\N{HANGUL SYLLABLE COE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 51201 (\N{HANGUL SYLLABLE JEOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %% [markdown]
# Latitude, Longtitude민 조작변수로 하여 iter 10으로 돌렸을 때

# %%
# 📌 1️⃣ 최적화된 위치 시각화 (위도-경도 산점도)
plt.figure(figsize=(10, 6))
scatter = plt.scatter(df_row["Longtitude"], df_row["Lattitude"], c=df_row["Predicted_Price"], cmap='viridis', alpha=0.8)
plt.colorbar(scatter, label="Predicted Price")
plt.xlabel("Longtitude (경도)")
plt.ylabel("Lattitude (위도)")
plt.title("📍 최적화된 위치와 예측 가격 (Scatter Plot)")
plt.show()
# Out:
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 128205 (\N{ROUND PUSHPIN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 52572 (\N{HANGUL SYLLABLE COE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 51201 (\N{HANGUL SYLLABLE JEOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %% [markdown]
# ## 조작변수로 BuildingArea를 포함시켰을 때

# %%
# 📌 1️⃣ 최적화된 위치 시각화 (위도-경도 산점도)
plt.figure(figsize=(10, 6))
scatter = plt.scatter(df_row["Longtitude_optimized"], df_row["Lattitude_optimized"], c=df_row["Predicted_Price"], cmap='viridis', alpha=0.8)
plt.colorbar(scatter, label="Predicted Price")
plt.xlabel("Longtitude (경도)")
plt.ylabel("Lattitude (위도)")
plt.title("📍 최적화된 위치와 예측 가격 (Scatter Plot)")
plt.show()

# %% [markdown]
# Latitude, Longtitude민 조작변수로 하여 iter 20으로 돌렸을 때

# %%
# 📌 1️⃣ 최적화된 위치 시각화 (위도-경도 산점도)
plt.figure(figsize=(10, 6))
scatter = plt.scatter(df_row_2["Longtitude"], df_row_2["Lattitude"], c=df_row_2["Predicted_Price"], cmap='viridis', alpha=0.8)
plt.colorbar(scatter, label="Predicted Price")
plt.xlabel("Longtitude (경도)")
plt.ylabel("Lattitude (위도)")
plt.title("📍 최적화된 위치와 예측 가격 (Scatter Plot)")
plt.show()
# Out:
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 128205 (\N{ROUND PUSHPIN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 52572 (\N{HANGUL SYLLABLE COE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 51201 (\N{HANGUL SYLLABLE JEOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
# 📌 1️⃣ 최적화된 위치 시각화 (위도-경도 산점도)
plt.figure(figsize=(10, 6))
scatter = plt.scatter(df_row_add_building_area_2["Longtitude_optimized"], df_row_add_building_area_2["Lattitude_optimized"], c=df_row_add_building_area_2["Predicted_Price"], cmap='viridis', alpha=0.8)
plt.colorbar(scatter, label="Predicted Price")
plt.xlabel("Longtitude (경도)")
plt.ylabel("Lattitude (위도)")
plt.title("📍 최적화된 위치와 예측 가격 (Scatter Plot)")
plt.show()
# Out:
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 128205 (\N{ROUND PUSHPIN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 52572 (\N{HANGUL SYLLABLE COE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 51201 (\N{HANGUL SYLLABLE JEOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 54868 (\N{HANGUL SYLLABLE HWA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %% [markdown]
# ## 원래 CSV 파일 분석

# %%
# 📌 2️⃣ 예측 가격 분포 확인 (히스토그램)
plt.figure(figsize=(10, 6))
sns.histplot(df_original["Price"], bins=30, kde=True, color='blue')
plt.xlabel("Predicted Price (예측된 가격)")
plt.ylabel("Frequency (빈도)")
plt.title("📊 예측된 가격의 분포 (Histogram)")
plt.show()
# Out:
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 50696 (\N{HANGUL SYLLABLE YE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 52769 (\N{HANGUL SYLLABLE CEUG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 46108 (\N{HANGUL SYLLABLE DOEN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %% [markdown]
# ## Latitude, Longtitude만 조작변수로 하여 iter 10으로 돌렸을 때

# %%
# 📌 2️⃣ 예측 가격 분포 확인 (히스토그램)
plt.figure(figsize=(10, 6))
sns.histplot(df_row["Predicted_Price"], bins=30, kde=True, color='blue')
plt.xlabel("Predicted Price (예측된 가격)")
plt.ylabel("Frequency (빈도)")
plt.title("📊 예측된 가격의 분포 (Histogram)")
plt.show()
# Out:
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 50696 (\N{HANGUL SYLLABLE YE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 52769 (\N{HANGUL SYLLABLE CEUG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 46108 (\N{HANGUL SYLLABLE DOEN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %% [markdown]
# ## 조작변수로 BuildingArea를 포함시켰을 때

# %%
# 📌 2️⃣ 예측 가격 분포 확인 (히스토그램)
plt.figure(figsize=(10, 6))
sns.histplot(df_row["Predicted_Price"], bins=30, kde=True, color='blue')
plt.xlabel("Predicted Price (예측된 가격)")
plt.ylabel("Frequency (빈도)")
plt.title("📊 예측된 가격의 분포 (Histogram)")
plt.show()
# Out:
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 50696 (\N{HANGUL SYLLABLE YE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 52769 (\N{HANGUL SYLLABLE CEUG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 46108 (\N{HANGUL SYLLABLE DOEN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %% [markdown]
# ## Latitude, Longtitude만 조작변수로 하여 iter 20으로 돌렸을 때

# %%
# 📌 2️⃣ 예측 가격 분포 확인 (히스토그램)
plt.figure(figsize=(10, 6))
sns.histplot(df_row_2["Predicted_Price"], bins=30, kde=True, color='blue')
plt.xlabel("Predicted Price (예측된 가격)")
plt.ylabel("Frequency (빈도)")
plt.title("📊 예측된 가격의 분포 (Histogram)")
plt.show()
# Out:
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 50696 (\N{HANGUL SYLLABLE YE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 52769 (\N{HANGUL SYLLABLE CEUG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 46108 (\N{HANGUL SYLLABLE DOEN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %% [markdown]
# ## 원래 CSV 파일 분석

# %%
# 📌 3️⃣ 3D 산점도 (위도, 경도, 예측된 가격)
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')
scatter = ax.scatter(df_original["Longtitude"], df_original["Lattitude"], df_original["Price"], c=df_original["Price"], cmap='plasma', alpha=0.8)
ax.set_xlabel("Longtitude (경도)")
ax.set_ylabel("Lattitude (위도)")
ax.set_zlabel("Price (가격)")
plt.colorbar(scatter, label="Price")
plt.title("🌍 공간적 가격 변화 (3D Scatter Plot)")
plt.show()
# Out:
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44221 (\N{HANGUL SYLLABLE GYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %% [markdown]
# ## Latitude, Longtitude민 조작변수로 하여 iter 10으로 돌렸을 때

# %%
# 📌 3️⃣ 3D 산점도 (위도, 경도, 예측된 가격)
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')
scatter = ax.scatter(df_row["Longtitude"], df_row["Lattitude"], df_row["Predicted_Price"], c=df_row["Predicted_Price"], cmap='plasma', alpha=0.8)
ax.set_xlabel("Longtitude (경도)")
ax.set_ylabel("Lattitude (위도)")
ax.set_zlabel("Predicted Price (예측된 가격)")
plt.colorbar(scatter, label="Predicted Price")
plt.title("🌍 공간적 가격 변화 (3D Scatter Plot)")
plt.show()
# Out:
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44221 (\N{HANGUL SYLLABLE GYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 127757 (\N{EARTH GLOBE EUROPE-AFRICA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44277 (\N{HANGUL SYLLABLE GONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %% [markdown]
# ## 조작변수로 BuildingArea를 포함시켰을 때

# %%
# 📌 3️⃣ 3D 산점도 (위도, 경도, 예측된 가격)
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')
scatter = ax.scatter(df_row["Longtitude_optimized"], df_row["Lattitude_optimized"], df_row["Predicted_Price"], c=df_row["Predicted_Price"], cmap='plasma', alpha=0.8)
ax.set_xlabel("Longtitude (경도)")
ax.set_ylabel("Lattitude (위도)")
ax.set_zlabel("Predicted Price (예측된 가격)")
plt.colorbar(scatter, label="Predicted Price")
plt.title("🌍 공간적 가격 변화 (3D Scatter Plot)")
plt.show()
# Out:
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44221 (\N{HANGUL SYLLABLE GYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 127757 (\N{EARTH GLOBE EUROPE-AFRICA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44277 (\N{HANGUL SYLLABLE GONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %% [markdown]
# ## Latitude, Longtitude민 조작변수로 하여 iter 20으로 돌렸을 때

# %%
# 📌 3️⃣ 3D 산점도 (위도, 경도, 예측된 가격)
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')
scatter = ax.scatter(df_row_2["Longtitude"], df_row_2["Lattitude"], df_row_2["Predicted_Price"], c=df_row_2["Predicted_Price"], cmap='plasma', alpha=0.8)
ax.set_xlabel("Longtitude (경도)")
ax.set_ylabel("Lattitude (위도)")
ax.set_zlabel("Predicted Price (예측된 가격)")
plt.colorbar(scatter, label="Predicted Price")
plt.title("🌍 공간적 가격 변화 (3D Scatter Plot)")
plt.show()
# Out:
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44221 (\N{HANGUL SYLLABLE GYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 50696 (\N{HANGUL SYLLABLE YE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %% [markdown]
# ## 원래 CSV 파일 분석

# %%
# 📌 4️⃣ 위도별 예측 가격 변화 확인 (선 그래프)
plt.figure(figsize=(10, 6))
sns.lineplot(x=df_original["Lattitude"], y=df_original["Price"], marker='o', color='red')
plt.xlabel("Lattitude (위도)")
plt.ylabel("Predicted Price (예측된 가격)")
plt.title("📈 위도별 예측 가격 변화 (Line Plot)")
plt.show()
# Out:
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %% [markdown]
# ## Latitude, Longtitude민 조작변수로 하여 iter 10으로 돌렸을 때

# %%
# 📌 4️⃣ 위도별 예측 가격 변화 확인 (선 그래프)
plt.figure(figsize=(10, 6))
sns.lineplot(x=df_row["Lattitude"], y=df_row["Predicted_Price"], marker='o', color='red')
plt.xlabel("Lattitude (위도)")
plt.ylabel("Predicted Price (예측된 가격)")
plt.title("📈 위도별 예측 가격 변화 (Line Plot)")
plt.show()
# Out:
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %% [markdown]
# ## 조작변수로 BuildingArea를 포함시켰을 때

# %%
# 📌 4️⃣ 위도별 예측 가격 변화 확인 (선 그래프)
plt.figure(figsize=(10, 6))
sns.lineplot(x=df_row["Lattitude_optimized"], y=df_row["Predicted_Price"], marker='o', color='red')
plt.xlabel("Lattitude (위도)")
plt.ylabel("Predicted Price (예측된 가격)")
plt.title("📈 위도별 예측 가격 변화 (Line Plot)")
plt.show()
# Out:
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %% [markdown]
# ## Latitude, Longtitude민 조작변수로 하여 iter 20으로 돌렸을 때

# %%
# 📌 4️⃣ 위도별 예측 가격 변화 확인 (선 그래프)
plt.figure(figsize=(10, 6))
sns.lineplot(x=df_row_2["Lattitude"], y=df_row_2["Predicted_Price"], marker='o', color='red')
plt.xlabel("Lattitude (위도)")
plt.ylabel("Predicted Price (예측된 가격)")
plt.title("📈 위도별 예측 가격 변화 (Line Plot)")
plt.show()
# Out:
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
# 📌 5️⃣ 경도별 예측 가격 변화 확인 (선 그래프)
plt.figure(figsize=(10, 6))
sns.lineplot(x=df_row["Longtitude"], y=df_row["Predicted_Price"], marker='o', color='green')
plt.xlabel("Longtitude (경도)")
plt.ylabel("Predicted Price (예측된 가격)")
plt.title("📈 경도별 예측 가격 변화 (Line Plot)")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 📌 기존 데이터(melb_split.csv) 로드 (인덱스를 유지)
melb_df = pd.read_csv("melb_split.csv")

# 📌 최적화된 가격 데이터(optimized_solutions.csv) 로드
opt_df = pd.read_csv("optimized_solutions_8_register.csv")

# 🔹 기존 데이터에 인덱스 추가 (0부터 시작)
melb_df = melb_df.reset_index()

# 🔹 최적화 데이터와 기존 데이터(인덱스 기준) 병합
merged_df = opt_df.merge(melb_df, left_on="index", right_on="index", how="left")

# 🔹 가격 변화 계산
merged_df["Price_Difference"] = merged_df["Predicted_Price"] - merged_df["Price"]
merged_df["Price_Percentage_Change"] = (merged_df["Price_Difference"] / merged_df["Price"]) * 100

####################추가##################
# 🔺🔻 가격 변화 아이콘 추가
def add_arrow(value):
    if value > 0:
        return f"🔺 +{value:,.0f}"
    elif value < 0:
        return f"🔻 {value:,.0f}"
    else:
        return "→ 0"

merged_df["Change_Indicator"] = merged_df["Price_Difference"].apply(add_arrow)
###############################################################################

# ✅ 데이터 확인
print(merged_df[["index", "Lattitude_optimized", "Longtitude_optimized", "Lattitude", "Longtitude", "Price", "Predicted_Price", "Price_Difference", "Price_Percentage_Change"]])
# Out:
#       index  Lattitude_optimized  Longtitude_optimized  Lattitude  Longtitude  \
# 0         0           -37.964077            144.950278  -37.90380   145.00010
# 1         1           -38.069070            144.972455  -37.75390   144.96120
# 2         3           -37.851565            144.907100  -37.88630   145.06600
# 3         6           -37.822580            145.019300  -37.82258   145.01930
# 4        11           -37.968547            144.950341  -37.78703   144.84569
# ...     ...                  ...                   ...        ...         ...
# 7108  13574           -38.164920            145.097578  -37.86780   144.83840
# 7109  13575           -38.164920            144.940734  -37.72530   144.93800
# 7110  13576           -38.044134            144.992195  -37.92980   145.16524
# 7111  13577           -38.097793            144.971719  -37.58905   144.93658
# 7112  13579           -37.787490            144.982088  -37.76588   144.99731
#
# ...

# %%
drop_tables = ['Suburb', 'Address', 'Rooms', 'Method', 'SellerG', 'Date', 'Distance', 'Postcode',
               'Bedroom2', 'Bathroom', 'Car', 'Landsize', 'YearBuilt', 'CouncilArea',
               'Regionname', 'Propertycount', 'Split']
merged_df = merged_df.drop(drop_tables, axis=1)
merged_df
# Out:
#       index  Lattitude_optimized  Longtitude_optimized  Predicted_Price Type  \
# 0         0           -37.964077            144.950278        2109025.0    h
# 1         1           -38.069070            144.972455        1761790.0    h
# 2         3           -37.851565            144.907100        1084780.0    u
# 3         6           -37.822580            145.019300         765180.0    u
# 4        11           -37.968547            144.950341        1777410.0    h
# ...     ...                  ...                   ...              ...  ...
# 7108  13574           -38.164920            145.097578         522035.0    u
# 7109  13575           -38.164920            144.940734        1444910.0    h
# 7110  13576           -38.044134            144.992195        1755090.0    h
# 7111  13577           -38.097793            144.971719        2175635.0    h
# 7112  13579           -37.787490            144.982088        1448150.0    h
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 📌 기존 데이터(melb_split.csv) 로드 (인덱스를 유지)
melb_df = pd.read_csv("melb_split.csv")

# 📌 최적화된 가격 데이터(optimized_solutions.csv) 로드
opt_df = pd.read_csv("optimized_solutions_add_BuildingArea_2.csv")

# 🔹 기존 데이터에 인덱스 추가 (0부터 시작)
melb_df = melb_df.reset_index()

# 🔹 최적화 데이터와 기존 데이터(인덱스 기준) 병합
merged_df_2 = opt_df.merge(melb_df, left_on="index", right_on="index", how="left")

# 🔹 가격 변화 계산
merged_df_2["Price_Difference"] = merged_df_2["Predicted_Price"] - merged_df_2["Price"]
merged_df_2["Price_Percentage_Change"] = (merged_df_2["Price_Difference"] / merged_df_2["Price"]) * 100

####################추가##################
# 🔺🔻 가격 변화 아이콘 추가
def add_arrow(value):
    if value > 0:
        return f"🔺 +{value:,.0f}"
    elif value < 0:
        return f"🔻 {value:,.0f}"
    else:
        return "→ 0"

merged_df_2["Change_Indicator"] = merged_df_2["Price_Difference"].apply(add_arrow)
###############################################################################

# ✅ 데이터 확인
print(merged_df_2[["index", "Lattitude_optimized", "Longtitude_optimized", "Lattitude", "Longtitude", "Price", "Predicted_Price", "Price_Difference", "Price_Percentage_Change"]])
# Out:
#       index  Lattitude_optimized  Longtitude_optimized  Lattitude  Longtitude  \
# 0         0           -37.795130            145.124548  -37.90380   145.00010
# 1         1           -37.795130            145.124548  -37.75390   144.96120
# 2         3           -37.795130            145.124548  -37.88630   145.06600
# 3         6           -37.795130            145.124548  -37.82258   145.01930
# 4        11           -37.795130            145.124548  -37.78703   144.84569
# ...     ...                  ...                   ...        ...         ...
# 7108  13574           -38.112776            144.755286  -37.86780   144.83840
# 7109  13575           -38.070349            144.995396  -37.72530   144.93800
# 7110  13576           -37.795130            145.124548  -37.92980   145.16524
# 7111  13577           -37.960065            144.962958  -37.58905   144.93658
# 7112  13579           -37.795130            145.124548  -37.76588   144.99731
#
# ...

# %%
merged_df_2
# Out:
#       index  Lattitude_optimized  Longtitude_optimized  Predicted_Price  \
# 0         0           -38.039951            144.968639        2107825.0
# 1         1           -38.051496            144.962836        1760940.0
# 2         3           -38.132327            144.931289        1113395.0
# 3         6           -38.182032            144.910829         733122.5
# 4        11           -38.104097            145.002822        1750750.0
# ...     ...                  ...                   ...              ...
# 7108  13574           -38.081074            144.988735         541215.0
# 7109  13575           -38.175219            144.937084        1444910.0
# 7110  13576           -38.104097            145.002822        1750750.0
# 7111  13577           -38.104097            145.002822        2183160.0
# 7112  13579           -37.849372            145.023057        1579520.0
#
#            Suburb              Address  Rooms Type Method        SellerG  ...  \
# ...

# %%
# 📊 1️⃣ 가격 변화 분포 히스토그램
plt.figure(figsize=(10, 6))
sns.histplot(merged_df["Price_Difference"], bins=30, kde=True, color='blue')
plt.axvline(0, color='red', linestyle='dashed')  # 가격 변화 0인 기준선
plt.xlabel("Price Difference (최적화된 가격 - 기존 가격)")
plt.ylabel("Frequency")
plt.title("📊 가격 변화 분포 (상승 vs 하락)")
plt.show()
# Out:
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44201 (\N{HANGUL SYLLABLE GYEOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 48320 (\N{HANGUL SYLLABLE BYEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
# 📊 1️⃣ 가격 변화 분포 히스토그램_2
plt.figure(figsize=(10, 6))
sns.histplot(merged_df_2["Price_Difference"], bins=30, kde=True, color='blue')
plt.axvline(0, color='red', linestyle='dashed')  # 가격 변화 0인 기준선
plt.xlabel("Price Difference (최적화된 가격 - 기존 가격)")
plt.ylabel("Frequency")
plt.title("📊 가격 변화 분포 (상승 vs 하락)")
plt.show()
# Out:
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44032 (\N{HANGUL SYLLABLE GA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44201 (\N{HANGUL SYLLABLE GYEOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 48320 (\N{HANGUL SYLLABLE BYEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
# 📊 2️⃣ 위도별 가격 변화 시각화
plt.figure(figsize=(10, 6))
sns.scatterplot(x=merged_df["Lattitude"], y=merged_df["Price_Difference"], hue=merged_df["Price_Difference"], palette="coolwarm", size=abs(merged_df["Price_Difference"]))
plt.axhline(0, color='black', linestyle='dashed')  # 기준선
plt.xlabel("Lattitude (위도)")
plt.ylabel("Price Difference")
plt.title("📍 위도별 가격 변화")
plt.show()
# Out:
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 128205 (\N{ROUND PUSHPIN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
# 📊 2️⃣ 위도별 가격 변화 시각화
plt.figure(figsize=(10, 6))
sns.scatterplot(x=merged_df_2["Lattitude"], y=merged_df_2["Price_Difference"], hue=merged_df_2["Price_Difference"], palette="coolwarm", size=abs(merged_df_2["Price_Difference"]))
plt.axhline(0, color='black', linestyle='dashed')  # 기준선
plt.xlabel("Lattitude (위도)")
plt.ylabel("Price Difference")
plt.title("📍 위도별 가격 변화")
plt.show()
# Out:
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 128205 (\N{ROUND PUSHPIN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 50948 (\N{HANGUL SYLLABLE WI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
# 📊 2️⃣ 위도별 가격 변화 시각화
plt.figure(figsize=(10, 6))
sns.scatterplot(x=merged_df["Lattitude"], y=merged_df["Price_Difference"], hue=merged_df["Price_Difference"], palette="coolwarm", size=abs(merged_df["Price_Difference"]))
plt.axhline(0, color='black', linestyle='dashed')  # 기준선
plt.xlabel("Lattitude (위도)")
plt.ylabel("Price Difference")
plt.title("📍 위도별 가격 변화")
plt.show()

# %%
# 📊 2️⃣ 위도별 가격 변화 시각화
plt.figure(figsize=(10, 6))
sns.scatterplot(x=merged_df["Lattitude"], y=merged_df["Price_Difference"], hue=merged_df["Price_Difference"], palette="coolwarm", size=abs(merged_df["Price_Difference"]))
plt.axhline(0, color='black', linestyle='dashed')  # 기준선
plt.xlabel("Lattitude (위도)")
plt.ylabel("Price Difference")
plt.title("📍 위도별 가격 변화")
plt.show()

# %%
# 📊 3️⃣ 경도별 가격 변화 시각화
plt.figure(figsize=(10, 6))
sns.scatterplot(x=merged_df_2["Longtitude"], y=merged_df_2["Price_Difference"], hue=merged_df_2["Price_Difference"], palette="coolwarm", size=abs(merged_df_2["Price_Difference"]))
plt.axhline(0, color='black', linestyle='dashed')  # 기준선
plt.xlabel("Longtitude (경도)")
plt.ylabel("Price Difference")
plt.title("📍 경도별 가격 변화")
plt.show()
# Out:
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 128205 (\N{ROUND PUSHPIN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44221 (\N{HANGUL SYLLABLE GYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
# 📊 3️⃣ 경도별 가격 변화 시각화
plt.figure(figsize=(10, 6))
sns.scatterplot(x=merged_df["Longtitude"], y=merged_df["Price_Difference"], hue=merged_df["Price_Difference"], palette="coolwarm", size=abs(merged_df["Price_Difference"]))
plt.axhline(0, color='black', linestyle='dashed')  # 기준선
plt.xlabel("Longtitude (경도)")
plt.ylabel("Price Difference")
plt.title("📍 경도별 가격 변화")
plt.show()
# Out:
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 128205 (\N{ROUND PUSHPIN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44221 (\N{HANGUL SYLLABLE GYEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/conda/envs/sklearn-env/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 48324 (\N{HANGUL SYLLABLE BYEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
# 📌 기존 데이터(melb_split.csv) 로드
melb_df = pd.read_csv("melb_split.csv")

# %%
# 🔹 기존 데이터에 인덱스 추가 (0부터 시작)
melb_df = melb_df.reset_index()

# %%
melb_df
# Out:
#        index       Suburb          Address  Rooms Type Method        SellerG  \
# 0          0     Brighton    18 Rooding St      3    h      S         Buxton
# 1          1       Coburg    11 Station St      3    h      S           Brad
# 2          2    Brunswick     106 Evans St      3    h      S            Ray
# 3          3     Carnegie     4/5 Anzac St      2    u      S  hockingstuart
# 4          4       Altona      64 Queen St      4    h      S           Greg
# ...      ...          ...              ...    ...  ...    ...            ...
# 13575  13575  Pascoe Vale      12 Coane St      3    h      S  hockingstuart
# 13576  13576     Mulgrave  27 Glencairn St      5    h      S            Ray
# 13577  13577  Craigieburn    111 Hanson Rd      4    h      S            Ray
# 13578  13578   Point Cook  89 Tristania Dr      4    h     SP             LJ
# 13579  13579    Northcote  31 Gladstone Av      3    h      S         Nelson
#
# ...
